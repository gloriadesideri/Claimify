# %%
# Import libraries

import os
import torch
import numpy as np
import pandas as pd
import plotly.graph_objs as go
from sklearn.manifold import TSNE
import scipy
from gensim.models.word2vec import Word2Vec
import re
import random
import plotly.express as px
import plotly.graph_objects as go



#sotpwords removal
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# # Prepare data

# %%
# Import data
claims_df = pd.read_csv('data/postprocessed/claims.csv')
# delete nans in the claims and answer column
claims_df = claims_df.dropna(subset=['claim'])
# build a vector for the claims
claims_str = np.array(claims_df['claim'])
claims_str
# Out:
# array(['Hunter Biden had no experience in Ukraine or in the energy sector when he joined the board of Burisma.',
#        'Donald Trump delivered the largest tax cuts in American history.',
#        'In Nigeria … in terms of revenue share, 20% goes to the local government.',
#        ...,
#        'Matt Hancock owns the company responsible for supplying the NHS.',
#        '£1 billion was given to 13 companies for PPE but no PPE has been supplied.',
#        'Mixing one tablespoon of 2% iodine and one cup of baby oil will create a substance that removes body hair.'],
#       dtype=object)

# %%
# remove newline character
claims_str = [claim.replace('\n', '') for claim in claims_str]

# %%
# download stopwords
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Gloria/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/Gloria/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# we have to remove the possessives since we noticed they appeared frequently in the claims
def remove_stopwords_and_possessive(tokens):
    stop_words = set(stopwords.words('english'))
    processed_tokens = []
    
    for token in tokens:
        # Remove trailing "'s"
        token = re.sub(r"'s\b", '', token)
        
        if token.lower() not in stop_words:
            processed_tokens.append(token)
    
    return processed_tokens

# %%
processed_sentences = []
    
for sentence in claims_str:
       
    word_tokens = word_tokenize(sentence)
    word_tokens = [word.lower() for word in word_tokens if word.isalnum()]
    processed_tokens = remove_stopwords_and_possessive(word_tokens)
    
    processed_sentence = ' '.join(processed_tokens)
    processed_sentences.append(processed_sentence)
processed_sentences
# Out:
# ['hunter biden experience ukraine energy sector joined board burisma',
#  'donald trump delivered largest tax cuts american history',
#  'nigeria terms revenue share 20 goes local government',
#  'biden pledged stop border wall construction give amnesty health care illegal immigrants',
#  'police shooting jacob blake gov tony evers gov mandela barnes call peace encourage calm',
#  'common law admission test clat 2020 conducted september 7 2020 planned',
#  '35 revenue goes states nigeria',
#  'margaret sanger racist believed eugenics goal founding planned parenthood eradicate minorities',
#  'joe biden voted irag war supported war serbia syria libya',
#  'biden take away second amendment',
#  'biden pledged defund police',
#  '45 nigeria revenue goes federal government',
#  'donald trump inherited stagnant economy rebuilt',
#  'joe biden voted iraq war supported wars serbia syria libya',
#  'president muhammadu buhari sign new police bill allow officers arrest without warrant',
#  'plant seeds restructure dna human saliva',
#  'actually saw revenues treasury increase lowered taxes 2017 rest assured democrats want know',
#  '2019 us police times likely kill killed criminal',
#  'greater proportion 16 year olds vote elections scotland wales austria 18 20 year olds',
#  'donald trump kept promises voters',
#  'edo modular refinery governor obaseki project',
#  'global average number judges magistrates number people kenya',
#  'kenya population 48 million one judge serving people',
#  'kenya population 48 million one judge serving people 2019',
#  'anxiety levels among young teenagers dropped coronavirus pandemic study suggested',
#  'kenyan judiciary even get 1 national budget',
#  'raise taxes anybody making new taxes people making less',
#  'counties striving reach 10 allocation agriculture recommended malabo declaration',
#  'kenya disposes cases',
#  'judiciary kenya average cases filed courts every year',
#  'average cases filed kenya courts every year',
#  'global average number judges magistrates number people kenya',
#  'kenya judiciary one magistrate serving people',
#  'judiciary even get 1 national kenyan budget',
#  'government schools india privatised',
#  'current ghana administration resulted decline unemployment rates 2015 2019',
#  'one gets spanish flu 50 chance dying',
#  'ghana economy previously grew form president mahama government average three successive years 7 per year current administration',
#  'kenya settles court cases year',
#  'global average number judges magistrates number people',
#  'kenya judiciary even get 1 national budget',
#  'kenya one magistrate serves people',
#  'kenya population 48 million one judge serving people',
#  'democrats condemned rioting occurred alongside recent protests',
#  'pizza place washington comet ping pong ties hillary clinton leading democrats',
#  'south africans drink amongst top drinkers world',
#  'south africans among top drinkers world',
#  'south african consume alcohol per person average anywhere else africa',
#  'south africans drink per person anywhere else africa',
#  '31 south african drink alcohol',
#  'south africans drink per person anywhere else africa',
#  'world bank currently rates nigeria one ten top performing countries business index',
#  'south africans among top drinkers world',
#  '31 south africans drink alcohol',
#  '31 south africans drink alcohol',
#  'joe biden officiated gay wedding white house 2016',
#  'democratic arizona superintendent public instruction kathy hoffman pushing sex education would teach kindergartners masturbation sexual positions',
#  'interface exposure notification system contact tracing programme developed apple google secretly inserted onto phones tracks user location',
#  'democratic arizona superintendent public instruction kathy hoffman sworn office seuss book',
#  'india supreme court recently changed motto satyamev jayate yato dharmastato jai',
#  'democrats recited us pledge allegiance tonight took god',
#  'democratic vp candidate kamala harris called young voters stupid',
#  'israel developed saliva test',
#  'children silent coronavirus',
#  'social security checks go postal service since 2013 secure',
#  'candace owens fired show one america news racist outburst',
#  'president trump president american history',
#  'us billionaires became 400 billion richer pandemic millions lost 600 week extra unemployment',
#  'messages google earth show deep states new home shows map setatspeed emohwen gardens near guantanamo bay cuba',
#  'usa major industrial economy unemployment rate triple',
#  'usa 4 worlds population 25 worlds cases',
#  'donald trump trying take away health care getting rid affordable care act',
#  'mughal gardens renamed rajendra prasad garden',
#  'trumps january 2018 travel ban unlawful',
#  'raising us federally required minimum wage 15 hour would give 40 million workers pay raise push wage scale everyone else',
#  'drinking vodka protects individual',
#  'bjp mp former union minister alphons kannanthanam sent mother dead body delhi kerala funeral without revealing died',
#  'drinking traditional chinese medicine tcm steroids along antibiotics onset symptoms cures',
#  'sarang jeil church jesus took preventative measure coronavirus government spread virus prevent rev jeon attending demonstration august 15th',
#  '2016 33 million americans voted mail',
#  'michigan us one three key states enabled donald trump win presidential election 2016 winning margin averaged two votes per precinct',
#  'trump administration disbanded pandemic response team given',
#  'auto workers across michigan could lost jobs barack obama joe biden',
#  'vice president biden president obama assembled pandemic playbook make sure america prepared protected',
#  'nigeria largest producer rice africa ranking 14th world',
#  'many scientific studies saying masks worn enclosed spaces elevators conference rooms outdoors',
#  'us envelopes used ballots general elections reveal party affiliation voter allowing postal workers toss votes',
#  'one states determined outcome 2016 presidential race winning margin averaged two votes per precinct two votes',
#  'sharp decline recently novel coronavirus cases new york gov andrew cuomo handling situation',
#  'president donald trump threatened delay election suggested leave office loses',
#  'social security beneficiaries count post office get checks',
#  'social security beneficiaries count post office get checks',
#  'vice president biden president obama assembled pandemic playbook make sure america prepared protected trump administration disbanded pandemic response team given',
#  'sweden require wearing masks public deaths due',
#  'beijing government announced chinese people travel united states buy products',
#  'ms dhoni exited cricket team refusing campaign bjp jharkhand election',
#  'warm water effective curing joint pain',
#  'walmart stores stopped accepting cash payments',
#  'warm water effective curing asthma',
#  'cold drinks main cause heart attacks',
#  'facebook deleted photo melania trump sister mother',
#  'uk prime minister boris johnson apologised colonial rule india',
#  'cold water affects internal walls stomach affects large intestine results cancer',
#  'late actor sushant singh rajput developed app could detect infection person breathing',
#  'warm water effective curing migraine',
#  'sweden despite never lockdown lower death rate spain italy united kingdom',
#  'warm water effective curing epilepsy',
#  'united states postal service advises customers never send cash mail',
#  'tricolour hoisted first time niagara falls mark 74th indian independence day',
#  'former president george bush supports democratic presidential ticket joe biden kamala harris',
#  'united states reached herd immunity',
#  'annabelle doll escaped warren occult museum 14th august 2020 3am',
#  'medical face masks designed worn differently depending health wearer masks worn colored side sick want spread germs around white side mask filter part worn facing wearer sick prevent germs getting',
#  'vitamin prevents infection reduces severity',
#  'media ignoring tragic death boy fatally shot neighbor wilson north carolina august 9 2020',
#  'murder oscar grant police officer united states never prosecuted da',
#  'former president pranab mukherjee india passed away',
#  'kamala harris called joe biden racist rapist',
#  'caused casualties wwi korean vietnam iraq wars',
#  'creativity contagious pass said albert einstein',
#  'kamala harris said trump gone regained rightful place white house look supported endorsed actions coming next',
#  'russia successfully developed vaccine passed checks',
#  'kamala harris descended enslavers inconvenient part history deep dark secret',
#  'democratic california kamala harris alameda county district attorney oscar grant black man shot killed oakland california',
#  'sarah huckabee sanders said government job protect health trade liberty safety end losing',
#  'president trump says hopes nfl season gets canceled due coronavirus',
#  'russia developed new vaccine fight',
#  'regular indian railways trains cancelled till 30th september 2020',
#  'virus airborne',
#  'little caesars offering free pizza anyone shares comments facebook post',
#  'amazon ceo jeff bezos offered free prime shipping ballots',
#  'nz green party delivered kiwibuild houses managed around 400 promise extra houses year nothing wishful thinking destined go way kiwibuild',
#  'office special assistant executive governor kano state graveyards',
#  'vaccines caused deaths philippines',
#  'amid coronavirus pandemic facebook changed privacy rules allowing use pictures posts shared users lawsuits',
#  'video shows people pakistan uprooting trees planted part imran khan plantation campaign consider planting trees unislamic',
#  'donald trump payroll tax deferral could leave american workers liable thousands dollars tax season could potentially leave programs like social security medicare weakened',
#  'choluteca bridge built 1996',
#  'choluteca bridge withstood hurricane 1998 river changed course longer flows bridge',
#  'cells may play role body immune response virus',
#  'according harry roque even people die 10 million cases country loss',
#  'australian govt handing nursing homes label covid main cause deaths death certificates',
#  'massive international study shows much lower mortality rate countries hydroxychloroquine prescribed patients',
#  'balbir singh converted islam participated demolition babri masjid',
#  '82 public wearing face masks translink buses trains',
#  'people day tested test trace programme united kingdom',
#  'madagascar found coronavirus medicine wipe virus stage within period six days',
#  'gop lawyer helped kanye west get ballot wisconsin usa actively working donald trump campaign',
#  'communist government kerala india impose blackout august 5 prevent people watching ram mandir bhoomi pujan ceremony',
#  'large controlled trial billion people shows lower death rate patients treated hydroxychloroquine',
#  'health human services secretary alex azar visit taiwan august 2020 breach international rules',
#  'usa cases tests',
#  'france approves use hcq treatment covid 19 trials proved successful 800 hospital commenced using',
#  'trump tulsa rally 12000 people 6000 reported axios others',
#  'angela merkel daughter adolf hitler justin trudeau son fidel castro barbara bush daughter aleister crowley',
#  'rule damage federal property courthouse go jail 10 years',
#  'test much',
#  'trump black community anybody possible exception abraham lincoln',
#  'african americans trump well best employment numbers ever making money ever made',
#  'late john lewis come trump inauguration come trump state union speeches',
#  'california going send tens millions ballots california place',
#  'covid deaths way spiked going going arizona going florida going texas',
#  'ghislaine maxwell boyfriend jeffrey epstein died jail people still trying figure happened suicide killed',
#  'infected fewer people h1n1 virus media hysteria prompted overblown response',
#  'usa tested people country',
#  'reports russia paid bounties offered pay bounties militants kill american soldiers never reached trump desk',
#  'violence portland getting better since federal agents went arrested lot people',
#  'millions ballots mailed nobody even knows going',
#  'south korea spikes covid cases nobody knows 300 deaths',
#  'devender sharma fabricated false positive reports patients order get admitted kidney harvesting',
#  'depending study look said either 68 5 6 individuals making unemployment job',
#  'us washington mayor exempted members congress mandatory 14 day quarantine travelling coronavirus high risk area attend funeral john lewis',
#  'devender sharma ran illegal kidney racket pretext coronavirus',
#  'vaccine developed bharat biotech available market august 15 2020',
#  'kenya judiciary get even 1 national budget',
#  '2018 south african police service officers accused 217 cases torture cases assault',
#  'married couple florida tito amanda watts arrested selling fake golden tickets heaven hundreds people',
#  'global average number judges magistrates number people',
#  'michigan senator gary peters known nothing skipped 84 small business hearings 89 hearings china',
#  'kenya courts dispose cases every year',
#  'kenya population 48 million one judge serving people',
#  'soon ram mandir also kitchen bhojanalya devotees visiting town offered free meals raghupati laddus prasadam',
#  'kenya one magistrate serving people',
#  'population 48 million kenya one judge serving people',
#  'delicious laddus prepared bhoomi poojan ceremony sri ramachandra janmabhoomi ayodhya',
#  'kenya average cases filed courts every year',
#  'kenya one magistrate serving people',
#  'average cases filed kenya courts every year',
#  'kenya president uhuru kenyatta said health experts indicated levels positivity rate countrywide fallen high 13 june 8 august described encouraging',
#  'judiciary even get 1 kenyan national budget',
#  'since 2002 south africa police force grown 50',
#  'south african police service kills three times people per capita united states police force',
#  'face became mandatory shops indoor public spaces northern ireland 1 august 2020',
#  'social distancing prevent spread coronavirus practiced funeral civil rights icon john lewis',
#  'uk new daily allowance peers house lords 2020',
#  'walt disney characters mickey minnie mouse twins',
#  'cases baranguay campus increased due sonagkaisa rally held july 27 2020',
#  'scores politicians others list sex cases newly unsealed ghislaine maxwell court documents',
#  'ratneshwar temple leans angle higher leaning tower pisa',
#  'wisconsin coronavirus funding spent',
#  'ghislaine maxwell tested positive jail',
#  'taylor swift says remove statue liberty',
#  'covid outbreak discovered oregon minks',
#  'philippines marcos dictatorship developed missile system china',
#  'tint tint htun former myanmar actress singer became buddhist nun died',
#  'government closed rafale deal 2012',
#  'russia offered bounties taliban kill troops afghanistan',
#  'south sudan government teamed world bank offer grants worth million entrepreneurs',
#  'john mahama presided higher inflation nana reduced inflation',
#  'john mahama presided decline ghana agriculture nana increased ghana agricultural output',
#  'uttar pradesh police india took several goats custody wearing masks',
#  'republican bill says medical malpractice suits 2024',
#  'new york state labor department giving essential workers hazard pay',
#  'actor sonu sood launched number may 26 facilitate migrants reach home number one easily reach sonu sood team help',
#  'hetero selling 6 vials remdesivir rs kukatpally',
#  'john mahama presided low industrial growth four years office nana increased industrial growth',
#  'reports recent 2017 reported 92 prevalence blood lead poisoning children villages nigerian state zamfara',
#  'tom hanks went national tv say covid 19',
#  'usa largely afghanistan',
#  'four ukrainian soldiers died taking part vaccine trials conducted usa',
#  'smartphone apps measure blood pressure heart rate oxygen levels asking press index finger camera',
#  'samajwadi party leader azam khan said water burial would take jalsamadhi invited bhumi pujan ram temple ayodhya august 5 2020',
#  'united nations delivered formal stand order trump administration july 2020 ordering president stop federal officers using force peaceful protesters portland',
#  'much exposure 5g literally fry human central nervous system',
#  'nigeria recorded million abortion cases 2012 alone figure represented double 1996 figures',
#  'face become exposed virus wear mask chin',
#  'florida five times better new jersey new york deaths per million people',
#  'unicef stated coronavirus large size cell diameter micro reason mask prevents entry',
#  '5g towers unleash severely damaging level radiation dna',
#  'susceptible radiation 5g technology fetuses utero children',
#  'due exterior anatomy male testicles especially susceptible 5g radiation lowers sperm count cellular radiation kills irreplaceable eggs females',
#  'us healthcare workers still enough ppe pandemic',
#  'apc luring abubakar shekau vice presidential ticket inducement end war',
#  'blm injures 1000 police officers kills36 people 8 billion damage',
#  'ghanan government presented inconsistent data free senior high school programme 2020 review budget',
#  'clint eastwood endorsed donald trump',
#  'wisconsin democrats say lawmakers neighbouring states implemented safety precautions spread state gop',
#  'infection rate among healthcare workers ireland highest world',
#  'jim carrey said elites eat whole babies christmas suffer better taste',
#  'us drug prices 2019 went first time 51 years',
#  'pm modi imposed president rule even single time since 2014',
#  'counties kenya allocated average budgets agriculture',
#  'county governments kenya continued adhere gender principle three counties kilifi nyeri migori gone higher representation male female cecs county executive committee members',
#  'target ended heroes helpers program pairs children police officers holiday shopping trips',
#  'kenya sanitation coverage 25 16',
#  'sanitation coverage kenya 25 16',
#  'federal high court restrained godwin obaseki incumbent edo state governor participating peoples democratic party gubernatorial primaries state',
#  'kenya allocation budgets agriculture financial year increase reported last year',
#  'counties kenya past year sustained average allocation 24 total budgets health sector',
#  'allocation agriculture increase reported last year',
#  'kenyan counties allocated average budgets agriculture',
#  'counties kenya striving reach 10 budget allocation agriculture recommended malabo declaration',
#  'study concludes mask wearers lower iq',
#  'kenya water coverage stands 63 57',
#  'kenyan counties allocated average budgets agriculture',
#  'sanitation coverage 25 16',
#  'kenya county governments continued adhere gender principle four counties mombasa kilifi nyeri migori gone higher representation male female cecs',
#  'debt australian budget borrowed start pandemic',
#  'allocation agriculture increase reported last year kenya',
#  'modi govt make origin label mandatory products gem platform',
#  'joe biden owns island next sex offender jeffrey epstein hideaway',
#  'counties allocated average budgets agriculture',
#  'allocation agriculture increase reported last year',
#  'little girl shown lying casket photo died',
#  'water coverage stands 63 57 kenya',
#  'mandatory vaccinations direct violation nuremberg code',
#  'kenyan counties past year sustained average allocation 24 total budgets health sector',
#  'water coverage kenya stands 63 57',
#  'man dies r n cooper hospital mumbai due medical negligence',
#  'upcoming shortage pepper coronavirus',
#  'new zealand authorised troops enter homes enforce quarantine',
#  'us home health workers receive low pay limited benefits 40 snap medicaid',
#  'indiana woman charged mail voter fraud delivered 400 ballots democrat box prechecked',
#  'usa setting record job numbers',
#  'mel gibson accused hollywood child sacrifices paedophillia',
#  'study finds diet heavy fermented cabbage lower south korea fatalities',
#  'greenhouse gases emitted ocean causing holes ozone layer ozone layer holes causing global temperatures rise',
#  'rare yellow turtle spotted balasore odisha',
#  'us space agency nasa added 13th star sign named ophiuchus zodiac',
#  'medical experts world health organization us centers disease control prevention cdc new england journal medicine warned wearing face masks cause severe health issues',
#  'former president united states theodore roosevelt said anger conservative lie anger liberal tell truth',
#  'july 2020 vaccines safe accelerated pace development',
#  'said cats dogs contract',
#  'united states space agency nasa added 13th zodiac sign named ophiuchus list existing 12 zodiac signs',
#  'netflix end turkish service production upcoming local drama blocked country government gay character',
#  'vaccine safety qualifications',
#  'madipur area delhi three jihadists killed minor boy middle road knife petty matter',
#  'joe biden wants end school choice',
#  'president trump tweeted lifes matter painted hollywood streets',
#  'cal cunningham north carolina 2020 democratic senate candidate voted raise taxes state 1 billion 2001',
#  'donald trump tweeted thinks child lifes matter painted streets hollywood',
#  'coronavirus bioweapon',
#  'anthony fauci director national institute allergy infectious diseases wrote reject notion virus get eventually careless lazy heartless stance',
#  'governor osun state gboyega oyetola abuja three days able see governor mai mala buni chairman progressives congress apc national caretaker committee',
#  'washing glasses soap prevent lenses fogging whilst wearing mask',
#  'hackers china hide phishing codes inside whatsapp good morning good night images videos steal personal information bank card information data',
#  'shanghai china international news asked subscribers send good morning good night images videos whatsapp',
#  'covid patient died outside medical shop siwan india constituency bihar health minister',
#  'black kid named tyrone woodfork arrested yesterday severely beating elderly tulsa oklahoma white couple raping killing wife leaving husband dead national media ignoring crime',
#  'bank america pledged 1 billion dollars black lives matter',
#  'trump administration done job virus come new york',
#  'motorcycle fatality orlando florida counted covid death',
#  'matt hancock claimed uk lockdown began 16th march 2020',
#  'workers gardenia factory philippines tested positive',
#  'nigeria ghana cote ivoire senegal guinea responsible 80 per cent cases west africa',
#  'azerbaijan threatened bomb nuclear power plant armenia',
#  'john hickenlooper former governor colorado accepted donations anadarko petroleum corp oil gas company involved 2017 fatal explosion exchange company penalized',
#  'us businesses refuse legal tender fined sued',
#  'free federal housing former inmates',
#  'betting online slot machines increased 25 lockdown',
#  'united states citizens get level benefits bidens policy would looking give illegal immigrants',
#  'democrats want abolish us police departments want abolish prisons guess',
#  'biden wants end mandatory minimums criminal sentences',
#  'vaccines responsible 50 million deaths spanish flu pandemic 1918',
#  'biden plans mandate carbon emissions homes offices new buildings 2030 basically means windows nothing',
#  'one key elements unity task force recommendations biden presumptive democratic presidential nominee sanders leading voice progressive democrats biden presumptive us democratic presidential nominee sanders leading voice progressive us democrats charter schools abolished',
#  'biden plans stop deportation',
#  'us unity task force seeks abolish immigration detention us',
#  'democrats want rejoin paris climate accord seek even higher level restrictions climate change',
#  'construction trump administration replaced already existing barriers',
#  'unity platform includes plan appoint social justice prosecutors order free violent criminals',
#  'abolish immigration detention detention come illegally detention',
#  'donald trump claimed biden mandate net zero carbon emissions home offices new buildings would mean windows',
#  'biden policy immigrants country illegally get welfare benefits united states citizens get looking give illegal immigrants',
#  'people wearing masks reported 281',
#  'going going rip wall taking',
#  'migrant arrests expulsions us along southern border',
#  'agenda proposes end cash bail releasing dangerous criminals onto us streets',
#  'bonnie henry issued advice living threat',
#  'united states one lowest mortality rates',
#  'former indian deputy chief minister rebel congress leader sachin pilot joined bharatiya janata party',
#  'philippine depositary receipts equal actual ownership philippines',
#  'clinical trials completed potential russian vaccine',
#  'obama administration stopped testing h1n1 swine flu pandemic',
#  'south africa expertise development trial range vaccines',
#  'russia sechenov university completed clinical trails vaccine',
#  'south africa expertise development trial range vaccines',
#  'sarah sachin pilot attacks gehlot tweet saying even big magicians start sweating turn delhi',
#  'indian student finds home remedy cure accepted world health organization',
#  'south africans right resist isolation quarantine found hsve virus',
#  'south africa established vaccine manufacturing capability',
#  'cobbler west bengal sanjoy rabidas scored 93 west bengal board exams also rss member',
#  'answering call empty bank account',
#  'prof stephen adei praises prof naana great leader',
#  '1920 mahashivratri celebrated karachi took 100 years completely eradicate festival mahashivratri celebration held annually karachi cancelled 2020',
#  'graphic world health organization lists 7 biggest brain damaging habits',
#  'pr stunt tv channel leads police warning phone starting 140',
#  'longer quarantine returned england exempt country july 10',
#  'proud amu alumnus scientist kushbu mirza promoted director isro alumnus aligarh muslim university 2nd muslim scientist abdul kalam hold rank isro',
#  'cdc may stop calling epidemic due remarkably low death rate',
#  'letter consultant hospital surrey claims hospitals empty pandemic',
#  'world health organization advertising jobs fight coronavirus says experience necessary',
#  'peter navarro said study showed astonishing 50 reduction mortality rate patients taking hydroxychloroquine',
#  'scottish government got summer economic update',
#  'deaths nearing zero early july 2020',
#  'people developing fungal lung infections due wearing face masks',
#  'founder ghana progressive people party ppp dr paa kwasi nduom tweeted jane opoku agyeman far better ghana current mahamudu bawumia',
#  'herbal drink made snake grass cure cancer killing cancer cells 24 hours',
#  'us centers disease control prevention said bubonic plague spread cough droplets',
#  'international students contributed 40 billion economy',
#  '1 million international students studied american universities school year',
#  'bubonic plague airborne spread infected person coughs',
#  'drivers canada face penalties three demerit points fine passenger car using mobile phone',
#  'ghana health minister kwaku claims president tired coronavirus fight due citizens reluctance adhere preventive protocols',
#  'president donald trump claimed nascar decision ban confederate flags nascar events caused lowest ratings ever',
#  'one politician died lost job worn masks pandemic',
#  'image new zealand shows rural new zealand town set remove trout statue',
#  'pandemic seen conspiracy theories emerge claims 5g vendors used lockdown australia elsewhere roll 5g networks without public knowledge accompanying claims expanded network may cause negative health effects people',
#  'pcr polymerase chain reaction tests coronavirus pierce barrier',
#  'israeli air force bombarded nuclear installations iran practically putting end nuclear ambitions',
#  'muslims failing understand government messaging responsible leicester local outbreak',
#  'ghislaine maxwell recently arrested associate jeffrey epstein tested positive jail',
#  'local government australian state victoria begun handing payment anyone tested positive',
#  'american rapper kanye west running president united states 2020 elections',
#  'obasanjo said second war nigeria',
#  'muslims use hand sanitiser religion',
#  'zara closed stores due effects covid19 pandemic economy',
#  'founder airbnb said pandemic 12 years efforts destroyed 6 weeks due effects covid19 pandemic economy',
#  'prime minister narendra modi inducted prathap nm karnataka builds drones defence research development organisation drdo',
#  'victoria secret declared bankruptcy due effects covid19 pandemic economy',
#  'tata motors come new electric car called evision run kms charged battery warranty',
#  'rolex discontinued production due effects covid19 pandemic economy',
#  'clothing company la chapelle closed 4391 stores due effects covid19 pandemic economy',
#  'viral video shows pakistani chinese soldiers celebrating 20 indian soldiers killed action galwan valley',
#  'dr vk srinivas vice president bharat biotech photographed first vaccine developed bharat biotech',
#  'one four ni adults risk hunger malnutrition',
#  'cartoon showing piglets given names indian national media outlets feeding pig face indian prime minister nerendra modi drawn american cartoonist ben garrison',
#  'people starting enter ers fungal lung infections wearing masks',
#  'donald trump tweeted told south dakota governor everyone fine without mask need close sic border california',
#  'ferdinand marcos left 90 wealth filipinos',
#  'budweiser admits several employees pissing beer tanks years',
#  'photos showing sewer sacks beaches boracay taken past administration former president benigno aquino iii',
#  'budweiser employee urinating beer tank 12 years',
#  'wearing face mask carrying gun class 4 felony',
#  'even common cold counted positive result',
#  'new zealand national debt risen nz120 billion',
#  'kapil sibal indian lawyer politician going challenge india government decision ban 59 chinese apps including tiktok india supreme court',
#  'everyone including essential workers compensated fema',
#  'taylor swift says remove statue liberty',
#  'muslim woman ordered drink target starbucks given cup isis written cup instead name',
#  'kary mullis nobel laureate inventor polymerase chain reaction pcr test used detect coronavirus said could used virus detection',
#  'whole foods stores accept cash payments',
#  'leicester gone back lockdown soon 5g coveage rolled',
#  'covid 19 symptoms 5g related',
#  'national security law target extremely small minority people breached law life property basic rights freedoms overwhelming majority hong kong residents protected',
#  'us congresswoman maxine waters california introduced bill 2020 erasing confederate history act 2020 rename 11 us states originally made confederacy',
#  'image purported show political billboard young arm new zealand national party shows culturally insensitive slogan towards māoris',
#  'charles krauthammer wrote former president barack obama non profit organizing action shadow government organization aimed resisting tearing constitutional republic know america',
#  'michelle obama surrender law license committed fraud',
#  'oklahoma 100 positive coronavirus test rate trump tulsa rally',
#  'surface air temperatures bottom world risen three times faster global average since 1990s',
#  'states suffered harshest restriction us coronavirus pandemic',
#  'black lives matter funded designed us democrats social weapon',
#  'us democratic party owned controlled corporate media monopoly',
#  'next major advantage pandemic deep state case made public voting highly insecure practice proven rampant fraud',
#  'president geingob namibia fined attended party hosted mark political party swapo south west africa people organisation 60th birthday coronavirus lockdown gatherings banned',
#  'us democratic nominee us president joe biden avoided interviews debates pandemic lockdowns',
#  'democrats deep state flooded us streets deadly drugs manufacture devastating epidemic addiction mass incarceration',
#  'us president barack obama directed deep state authorize millions funding wuhan institute virology finance global biological attack timed release within election year',
#  'polymerase chain reaction pcr tests scientifically meaningless',
#  'removal cards kill coronavirus',
#  'drinking water protect',
#  'keir starmer stopped jimmy savile charged 2009',
#  'ministry ayush government india approved patanjali',
#  'seven people shot neighbourhood newark june 2018',
#  'jay inslee claims first governor implement public option health insurance plan',
#  'americans support roe wade',
#  'idli healthiest breakfast item whole world certified unesco',
#  'beto said want repeal section 1325',
#  'south africa number one killing women internationally',
#  'taiwanese ministry justice imposed following restrictions hong kong citizens applying emigrate accept family reunion applications people immediate family accept applications accept significant investors',
#  'average family america forks income local hospital irs',
#  'united states annual arms control compliance report address withdrawal arms trade treaty att',
#  'australia going keep borders closed 2021 due coronavirus',
#  'surcharges applied usa',
#  'us annual arms control compliance report mulling resumption nuclear tests',
#  'us annual arms control compliance report blocking negotiation biological weapons convention bwc verification protocol',
#  'honor guard soldiers march tomb unknown soldier arlington cemetery carry live ammunition',
#  'us annual arms control compliance report withdrawal abm jcpoa inf open skies treaty',
#  'indian marketplace livfavir manufactured livealth biopharma cheaper glenmark fabiflu',
#  '1977 president joe biden said integrating black students would turn schools racial jungle',
#  'issues polling places kentucky',
#  'gargling salt water concoction drinking water salt vinegar kill virus causing',
#  'country currently functioning track trace app',
#  'british prime minister boris johnson speaking british parliament stated country currently functioning track trace app countering',
#  'transactions google pay protected reserve bank india indian law',
#  'unused tests already showed positive results found tuscaloosa alabama',
#  'video showing emergency services helping patients streets pune deccan corner area june 2020 real',
#  'coronavirus cases increasing people tested virus',
#  'glenmark pharmaceuticals received approvals drug controller general india manufacture market favipiravir drug treat patients',
#  'june 2020 46 us states centers open north carolina one four states',
#  'nigeria debt burden made country broke',
#  'viral infographic shows risk percentage community transmission various states india',
#  'june 2020 nigerian debt servicing obligations stood billion',
#  'president trump said coronavirus testing makes look bad said people slow testing',
#  'former us president barack obama declared family leave canada donald trump wins',
#  'june 2020 99 nigerian revenue committed debt servicing alone',
#  'masks violate us department labor occupational safety health administration minimum oxygen level respiratory protection standard',
#  'alex jones claimed infowars website killing older people',
#  'president trump tweeted anyone ordered ticket tulsa rally attend arrested face powerful charges',
#  'government india issued memorandum directed google apple restrict several chinese applications respective stores immediate effect',
#  'alex jones claimed infowars website hospitals received every patient knowingly misdiagnosed patients pandemic',
#  'cloth masks trap carbon dioxide risk health',
#  'cloth masks filter anything',
#  'alex jones claimed infowars website united nations said economic crisis caused pandemic good thing',
#  'alex jones claimed infowars website areas told people never remove masks pandemic',
#  'issues warning possible phishing attacks',
#  'phishing attack seemed like official communique pandemic expected launched june 21 2020 onwards major metropolitan cities india',
#  'doctors banned social media pandemic calling pandemic hoax',
#  'surgical masks designed approved sterile environments every time person puts surgical mask breathing germs everywhere went changed thrown every minutes non sterile environment',
#  'alex jones claimed infowars website patients us hospital ships pandemic',
#  'vijaya hospital founder son died',
#  'china manufactured china goods indian market',
#  'revenue committed debt servicing alone',
#  'kamala harris vowed vengeance trump backers',
#  'first quarter 2020 nigeria revenues stood n950 billion',
#  'debt servicing obligations nigeria stood billion',
#  'since crisis disinformation scale never seen',
#  'melania trump tweeted support india following clash galwan valley',
#  'donald trump melania trump angela merkel benjamin netanyahu tweeted support india following clash galwan valley',
#  'nigeria bears 50 global sickle cell burden',
#  'nic government india directed regional executive representatives google india apple india restrict functioning chinese applications respective stores per instructions ministry electronics information technology meity including 15 apps particular include tiktok club factory shein vivo video among others',
#  'prime minister israel benjamin netanyahu tweeted stand india clash indian army chinese pla',
#  'pla released names 56 chinese soldiers died galwan valley',
#  'telangana govt released guidelines reopen schools state',
#  'chancellor germany angela merkel tweeted stand india clash indian army chinese pla',
#  'first lady us melania trump tweeted stand india clash indian army chinese pla',
#  'police departments germany defunded eliminated nazis hermann goering',
#  'prime minister israel benjamin netanyahu tweeted support india following clash galwan valley',
#  'shinzo abe prime minister japan tweeted stand india clash indian army chinese pla',
#  'us president donald trump tweeted support india following clash galwan valley',
#  'every two babies born sickle cell world one nigerian',
#  'ghana health service central regional director halts mass coronavirus testing',
#  'gov evers refused identify discipline staff member secretly taped conversation gop leaders',
#  'grocery store worker wore mask hours time got lung infection pleurisy breathing bacteria',
#  'public health england issued new guidance encourages public consider taking vitamin supplements community lockdownds due covid19',
#  'huawei technologies secretly control iran skycom tech co ltd',
#  'pregnant women susceptible',
#  'viral message claims facebook make private photos public',
#  'people recourse public funds yet able claim free school meal vouchers uk',
#  'steroid dexamethasone drug patients',
#  'nancy green aka aunt jemima first black millionaire sold pancake mix general mills corp',
#  'donald trump made juneteenth famous described wall street journal interview june 17 2020 prior planning rally june 19 nobody ever heard',
#  'myanmar launch satellite provide free internet citizens',
#  'establishing one world government part un goals',
#  'study conducted world health organization major hospitals found become weaker harmless',
#  'herbal medicine tanzania cure',
#  'former president barack obama born kenya according birth certificate',
#  'north korea blew office used south korea talks',
#  'denis mukwege medical doctor nobel peace laureate democratic republic congo resigned congolese government coronavirus response taskforce team asked manipulate numbers patients',
#  'america violent cities way democratic politics',
#  'myanmar citizens get free phone internet',
#  'five chinese soldiers killed border dispute india june 2020',
#  'boy scouts america committed act racial injustice',
#  'expansion ballots would increase chance theft usa',
#  'absentee voters usa go strict process',
#  'boy scouts supporting black lives matter required earn diversity badge',
#  'comedian steve harvey wrote feel trump post',
#  'us house speaker nancy pelosi violated military tradition gave folded us flag brother george floyd killed police custody minneapolis late may 2020',
#  'atlanta police said white supremacists shot seven black people killing two shooting atlanta saturday june 13 2020',
#  'president donald trump campaign seeking minority actors hold signs june 20 rally tulsa oklahoma',
#  'aicte conducting online survey related university exam',
#  'strict lockdown reimposed delhi starting june 18 2020 contain spread',
#  'mexico leaving difficult stage pandemic consider worst',
#  'actor matt damon planning leaving united states australia get away president trump',
#  'milwaukee health department declared racism public health crisis 2019',
#  'milwaukee declared racism public health crisis 2019',
#  'ministry home affairs india decided implement complete lockdown june 18 2020 four weeks',
#  'sarah huckabee sanders posted conspiratorial tweet claimed odd anitfa insurgency happened loses steam odd happened moment impeachment failed odd impeachment happened moment russian hoax failed russian hoax happened hillary lost notice pattern',
#  'police officer charged killing george floyd still eligible pension benefits',
#  'nascar bans confederate flag',
#  'daughters confederacy sued nascar violating first amendment',
#  'asymptomatic patients need isolation complete destroying economy world complete',
#  'external reserves nigeria grew billion april 29th 2020 36 billion may 2020',
#  'biker gangs unite drive antifa seattle',
#  'trump said christians thought bible photo op beautiful',
#  'president muhammadu buhari nigeria says gdp grew 2018 2019 declined first quarter 2020 result decline global economic activities due pandemic',
#  'trump said lot people defunding police means breaking police forces giving money',
#  'black lives matter scotland produced posters stickers phrases kill white sight',
#  'president muhammadu buhari nigeria said witnessed 11 quarters consecutive gdp growth since exiting recession',
#  'nigeria gdp grew 2018 2019 declined first quarter 2020 result decline global economic activities due pandemic',
#  'every single economy world suffered decline due pandemic',
#  'president muhammadu buhari nigeria said revenue cocoa sesame seed increased million 153 million',
#  'world health organization offering jobs social media help fight coronavirus pandemic',
#  'president muhammadu buhari nigeria said nigeria rated one top ten reforming countries',
#  'nigeria external reserves grew billion 29 april 2020 36 billion may 2020',
#  'president donald trump said looting starts shooting starts phrase two meanings',
#  'prescription written dr raj kamal agarwal prescribes medicine prevent cure',
#  'nigeria witnessed 11 quarters consecutive gdp growth since exiting recession 2016',
#  'nigeria rated one top ten reforming countries',
#  'parliament kenya sits three days week',
#  'kenyan judiciary sits six days week',
#  '100 irish slaves dumped overboard drown 18th century ships supplies running low',
#  'kenya judiciary almost employees',
#  'kenyan judiciary almost employees 2019',
#  'kenyan parliament getting ksh38 billion judiciary getting ksh18 billion basically 50 parliament allocation 2020',
#  'white suspect sentenced two years jail black suspect sentenced 26 years prison florida judge',
#  'british writer former communist philip spratt wrote though economically advanced culturally backward bengal contrast economically backward culturally advanced',
#  'irish catholics sold slavery 16th century',
#  'amount set aside repayment debt kenya much higher money treasury cabinet secretary ukur yatani putting together development expenditure',
#  'post shared facebook claims president donald trump approved million mass production herbal tonic touted madagascar president remedy',
#  'first slaves shipped american colonies 1619 100 white children ireland',
#  'law ireland 1619 held sin kill irishman dog brute',
#  'kenya judiciary sits six days week',
#  'kenya dealing situation amount set aside repayment debt much higher money ukur yatani putting together development expenditure',
#  'south african police service kills three times people per capita united states police force',
#  'vitamin b17 deficiency causes cancer',
#  '2018 south african police service officers accused 217 cases torture cases assault',
#  'trump remove troops germany',
#  '558 people killed south african police 2018 201 people died police custody',
#  '20 african americans jobs could work home covid 2020 crisis',
#  'consuming grape seeds bitter almonds cure cancer',
#  'national polls never predicted president democratic party us presidential elections',
#  'mixing lemon baking soda kill coronavirus',
#  'walmart tweeted wont rebuilding walmarts cities without police',
#  'north korea cancels communication south korea',
#  '52 free horses june 2020 needed rehoming ohio owner died',
#  'vitamin helps protect',
#  'assam government announces 100 free admission students colleges postgraduate level colleges allowed charge student anything saraswati puja charges excursion fees prospectus fees colleges found charging students anything admission strict actions taken',
#  'democratic assembly woman 143rd district new york monica wallace significantly people died two months died overdoses last year year',
#  'federal police use chemical irritants clear area around john church washington',
#  'fact check lebron james say wants nothing white people',
#  'first prime minister india pt jawaharlal nehru gave interview playboy magazine article published 1963',
#  'drinking pigeon membrane slurry cures coronavirus',
#  'thyrocare labs sealed thane testing',
#  'wastewater early indicator coronavirus outbreak',
#  'video india shows putting basil leaves camphor inside masks purify air protect',
#  'phishing attack issued warning sponsored chinese army',
#  'united nations creating new country nigeria called ambazonia new state cameroon',
#  'joe biden stated debate july 2019 fossil fuels including coal fracking would eliminated biden administration',
#  'june 2020 autopsies performed italian pathologists proved disseminated intravascular coagulation ought fought antibiotics antivirals anticoagulants',
#  'donald trump elected us president',
#  'prince andrew accused pedophilia extremely close jeffrey epstein',
#  'uv rays sunlight kill corona virus',
#  'virus bacterium',
#  'batch adrenochrome purported compound formed oxidation adrenaline made wuhan china',
#  'federal reserve treasury merged making donald trump chairman global banking system people money',
#  'us deployed troops europe training without masks hand sanitizer',
#  '600 mexican drug cartels recently arrested one biggest busts history',
#  '298 saudi arabian royals billionaires lawyers judges recently arrested crimes corruption',
#  'duke duchess sussex left british royal family due family child traffickers',
#  'bill gates pushing vaccines global depopulation owns 15 world health organisation business also owned george soros rockerfellers',
#  'prince harry meghan markle left royal family',
#  'us economy crashed pandemic drain corrupt coins best achieved day lock money back people government grants',
#  'entire world lockdown pandemic',
#  '5g rolled world wide time world lockdown pandemic',
#  'harvey weinstein hollywood film producer arrested sex crimes suddenly contracted coronavirus',
#  'thousands arrests made us child trafficking human trafficking sex abuse media reporting nurses coming forward speaking publicly fact treating hundreds children hospitals right coronavirus malnutrition extremely deformed extreme psychiatric damage due trauma',
#  'rashida tlaib claimed 2020 detroit spend 294 million police 2019 9 million health',
#  'last time police officer successfully prosecuted uk concerning death somebody custody 1969',
#  'underground tunnel systems used decades traffick people sex slaves organ harvesting across globe currently military operation happening lead us president uncover children arrest involved stop',
#  'pandemic helped bolster relationship china middle eastern countries',
#  'bird shutting service middle east scrapping many scooters',
#  '600 elephants killed kerala every year',
#  'supreme court india ruled favour renaming country languages',
#  'india let 65 lakh tonne grain go waste four months even poor went hungry',
# ...
#  'aspirin combined honey lemon juice kill coronavirus',
#  'virtually could predicted would spread exponentially february 2020 may 2020',
#  'jack said 2020 year thinking dreams plans ensure stay alive',
#  'seating arrangement sudarshan 35mm cinema rearranged suit physical distancing norms',
#  'department telecom india made internet free till may 17 2020',
#  'new york andrew cuomo california gavin newsom praise trump amid pandemic',
#  'biden pelosi attacked trump pandemic response',
#  'nigerian vice president yemi osibanjo said plead nigerians retaliate fulani herdsmen killings pray instead federal executive praying hard',
#  'pandemic allow deployment dangerous 5g telecommunications towers',
#  'retail milk prices gone farmer price pay dropped',
#  'cdc made deaths disappear',
#  'pandemic real',
#  'employees punjab national bank branch loni ghaziabad outskirts delhi found corona positive may 2020',
#  'whatsapp text lists 21 dos ts resume life lockdown ascribed indian council medical research icmr new delhi india',
#  'country lockdown protests',
#  'top white house coronavirus adviser anthony fauci served clinton foundation board directors 20 years',
#  'ron johnson changed stance independence inspectors general related president',
#  'news report shows police manhandled crowd dispersing mosque namaz',
#  'central state governments paying migrants return homes',
#  'men likely die women',
#  'satire website posted story aoc proposed ending social security benefits age 75',
#  'soviet leader nikita khrushchev said speech children children live communism americans gullible',
#  'professor tasuku honjo said coronavirus natural',
#  'professor tasuku honjo worked wuhan laboratory china four years',
#  'cdc recommend people healthy wear facemasks',
#  'pennsylvania us refused service store wearing mask call department health report store',
#  'trader joe giving away chance get 250 coupon',
#  '100 indian nurses jhalawar resigned jamaatis spit',
#  'sam club giving away 250 coupons everyone',
#  'democrats 5717 bill would implement 30 tax gun sales 50 tax ammunition sales',
#  'cdc stopped reporting flu deaths low',
#  'children seem getting',
#  'virus simply exist',
#  'facebook post defending british government role current nhs equipment shortages written jennifer saunders',
#  'new york one 12 states usa average gallon gas costs',
#  '100 nurses rajasthan jhalawar india resigned misconduct members tablighi jamaat organisation claim spitting',
#  'australia covidsafe app traces monitors location user',
#  'cares act introduced 24 2019',
#  'us president donald trump tried defund national institute health',
#  'declassified fbi files show biden plotted kidnap john kennedy jr',
#  'wisconsin us contact tracing program pandemic speak',
#  'probability coronavirus could reduce 70 carrier healthy person wearing masks',
#  'kim jung un dead',
#  'supreme leader north korea kim jung un seriously ill',
#  'indian government giving willing citizens rs 1000 aid scheme',
#  'presidents lincoln kennedy assasinated trying end federal reserve banking system',
#  'without donald trump china travel ban millions would died coronavirus',
#  'april 22 period weeks uk exactly less deaths exact period weeks 2018',
#  'usa mosques allowed remain open services churches',
#  'photo billboard united states highlights advice islam prophet regarding guidelines pandemic',
#  'home minister anil deshmukh said hindu among arrested palghar lynching incident',
#  'actor aamir khan distributed 1kg packets flour containing rs sums mumbai',
#  'law requires rent mortgage refunds',
#  'patients united states denied ventilator',
#  'senator joni ernst reversed support coronavirus relief plan offered nearly half trillion dollars small businesses hospitals testing',
#  'former nigeria vp abubakar claims economy price oil lower president obasanjo abubakar assumed office 29 may 1999 today',
#  'wisconsin clearly seeing decline covid infections',
#  'biden campaign correct saying top cdc official',
#  'novel coronavirus spreading us early november 2019',
#  'coronavirus started spreading us november 2019',
#  'nigeria debt paid time former president obasanjo vp abubakar exited office 2007',
#  'united nations economic commission africa projecting africa growth drop perhaps lower',
#  'safer home plan implemented wisconsin us pandemic prevented death least 300 wisconsinites',
#  'virus miracle miracles miracle miracles children die get ill end intensive care 20 years old',
#  'quinine found tonic water along zinc daily kill',
#  'long term unemployed year nearly halves chances ever getting back employment',
#  'image shared facebook times claims 42 democratic senators plus two independents voted sending direct payments americans part coronavirus economic stimulus package',
#  'first lady aisha buhari claims husband muhammadu buhari dead',
#  'convalescent plasma therapy showing promise',
#  'half hour meditation twice day stay away',
#  'keep room temperature degrees celsius prevent',
#  'patient energy run half hour twice day burn cough inside',
#  'drinking milk three times day shilajit licorice mulethi five days help beat virus',
#  'drinking milk honey empty stomach antidote',
#  'president buhari nigeria decided resign nigerians',
#  'drinking ash phyllostachys nigra black bamboo mixed honey cow milk potent treatment',
#  'china halted exports face masks us coronavirus pandemic',
#  'former president olusegun obasanjo donated 5000 naira nigerians',
#  'prior nigeria former chief staff abba kyari death kyari flown united kingdom medical treatment body later cremated',
#  'barcodes tell consumers product manufactured',
#  'chief staff president nigeria mallam abba kyari died ulcer coronavirus',
#  'seasonal flu killed people united states',
#  'vaccines contain cells aborted fetal cells',
#  'chinese products identified first three digits barcode',
#  'always possibility iatrogenic reaction vaccine',
#  'boko haram leader shekau says ready surrender',
#  'autopsy reports suggest jeffrey epstein likely died suicide august 2019',
#  'immunization compulsory canada',
#  '26 members one family jahangirpuri delhi tested positive coronavirus april 17 2020',
#  'immunization mandatory united states',
#  'deaths year us swimming pools shut country',
#  'donald trump tweeted 2009 obama handling whole h1n1 pandemic terrible president responsibility becomes crisis like whether entirely blame john mccain matter would never let thousands americans die pandemic office',
#  'jay leno dead 71',
#  'africans living china forced sleep outside cold chinese nationals blame rising number new coronavirus cases country',
#  'video showing policemen picking currency notes lying road indore shared claim thrown purpose spread coronavirus',
#  'lady michelle obama slam country music industry saying genre morons',
#  'sparing essential workers deadly',
#  'joe biden said osha occupational safety health administration enforcing coronavirus guidelines donald trump us president',
#  'us centers disease control prevention lied number deaths caused combining count pneumonia influenza fatalities',
#  'drug diamox often used treatment sickness cure coronavirus',
#  'countries reopened saw increase coronavirus infections',
#  'alcohol plays major role killing coronavirus throat sanitizer',
#  'employee funeral home new york city accidentally cremated taking nap 2020 crisis',
#  '150 health workers quarantined max hospital saket',
#  '1st amendment comes 13th 14th bible clearly approves owning slaves stated david green fox news morning',
#  'trump claims ultimate authority override states virus measures',
#  'us media minimized risk new coronavirus start',
#  'squad want bible deemed hate speech',
#  '150 foreigners attended spiritual leader jaggi vasudev aka sadhguru event march 2020 led corona cases tamil nadu foreigners quarantined isha yoga center',
#  'june 2017 conservative mps voted pay rise nurses',
#  'states like montana nebraska getting federal stimulus money per reported case new york state yet getting per case',
#  'ny exhausted funeral home employee cremated mistake taking nap',
#  'coronavirus originated outside china',
#  'ratan tata said experts predicting huge downfall economy due corona know much experts know sure know anything value human motivation determined efforts',
#  'november 2019 pirbirght institute funded bill gates granted european patent number ep coronavirus vaccine may used treat humans',
#  'united states cdc centers disease control prevention admitted federal court studies support claim vaccines cause autism',
#  'october 2019 bill gates sponsored event 201 simulation estimated 65 million people would killed coronavirus',
#  'aadhaar enabled payments work till april 14 india',
#  'former president barack obama gave million lab wuhan china',
#  'government planning force americans take vaccinations coronavirus pandemic help bill gates',
#  'kalonji black cumin seeds contain 100 hydroxychloroquine cure coronavirus',
#  'bill gates owns patent vaccine coronavirus',
#  'las vegas hotels donated food rooms emergency personnel except one trump international hotel las vegas',
#  'bill gates partner lab wuhan china',
#  '5g radiation harmful human health',
#  'north carolina small minority states requires absentee ballot signed two witnesses notary public',
#  'image shared facebook purportedly shows former vice president joe biden biting young girl cheek',
#  'vandana tiwari died attacks muslims went screen',
#  'nigerian finance minister claims nigeria lost n700 billion naira relief funds due fire',
#  'resisted blacklisting isis',
#  'n13 billion devoted state house clinic last five years',
#  'nigeria paid entire foreign debt',
#  'la county sheriff deputies arrested surfer violating state order',
#  'flu vaccine work flu eliminated',
#  'senator bernie sanders yet endorsed joe biden president',
#  'price oil lower president obasanjo abubakar assumed office 29 may 1999 today',
#  'united nations economic commission africa projecting africa growth drop perhaps lower pandemic',
#  'price oil lower president obasanjo abubakar assumed office 29 may 1999',
#  'lot fraudulent voting us elections',
#  'sanders ended fight democratic nomination',
#  'world health organisation states deaths per year associated respiratory illnesses linked seasonal flu',
#  'novel coronavirus pandemic hit globe nigeria spent 42 earnings debt servicing',
#  'n13 billion devoted state house clinic last five years',
#  'restaurants hotels india would closed till october 15 2020 due coronavirus',
#  'united nations economic commission africa projecting africa growth drop perhaps lower',
#  'price oil lower president obasanjo abubakar assumed office 29 may 1999 today yet paid nigeria entire foreign debt',
#  'nigeria spent 1 billion naira text messages',
#  'state california admitted court settlement million people voted improperly us elections 2019',
#  'british prime minister boris johnson admitted hospital subsequently died',
#  'government india monitoring forms communications online telephonic',
#  'two nurses intensive therapy units itus swansea wales died three ventilated',
#  'illegal hold election mail ballots every registered voter',
#  'consuming ewedu cure',
#  'british author david icke claimed pandemic orchestrated supernatural forces attempting dismantle world economic system control population using new technologies like 5g',
#  'test detect',
#  'cadbury gave away 500 free baskets cadbury chocolate celebrate 196th anniversary',
#  'british author david icke claimed microscope images exosomes virus causes exactly',
#  'india government going cut pension employees 30 per cent terminate age 80 order divert funds towards managing health services tackle adverse effects coronavirus pandemic country',
#  '5g antennas fire la spezia italy',
#  'british author david icke claimed global pandemics always follow introduction new technologies',
#  'supreme court united states issued order remove ilhan omar congress',
#  'link launch 5g outbreak 2019',
#  'doctors scientist political figures say need cancel mardi gras',
#  'dr charles lieber harvard university arrested manufacturing novel coronavirus collusion china',
#  'people lupus take hydroxychloroquine protection',
#  'barack obama told africans reject coronavirus vaccines march 2020',
#  'data philippine general hospital claims correlation grocery shopping',
#  'lighting diya candle kill coronavirus',
#  'united states done testing infections eight days south korea done eight weeks',
#  'majority doctors said hydroxychloroquine effective coronavirus treatment',
#  'nhs doctor spoke lack ppe bbc suspended',
#  'published 4step lockdown procedure countries need follow control coronavirus',
#  'testing kits imported britain supplied china contaminated coronavirus',
#  'bill withers left 2 million estate trump campaign',
#  'viral video shows fbi seizing face masks sent china',
#  'video shows hindu priest pinned policeman',
#  'ranked sri lanka fifth best country pandemic response',
#  'military rescued malnourished caged children tunnels',
#  'prince charles cured covid ayurveda medicine',
#  'morel mushrooms source coronavirus',
#  'democratic presidential candidate joe biden called coronavirus hoax',
#  'michael bloomberg poll well mayor handling crisis',
#  'covid virus gone south korea residents stayed home three weeks',
#  'alcohol weakens immune system making difficult body fight infections',
#  'viruses really common colds gone bad defeated fruits vegetables strong immune system',
#  'coronavirus part conspiracy designed introduce new world order',
#  'barack obama urged africans reject vaccines',
#  '52 group admins whatsapp dadar cyber crime police station misleading fowards group',
#  'madagascan herbal drink called treatment cure',
#  'radiation cell phones 5g towers currently killing people coronavirus',
#  'romanian workers brought seasonal british farm work despite huge interest roles british people',
#  'air india evacuating indians stranded uk',
#  '70 contagion probability carrier wearing mask wearing mask 5 contagion probability carrier wearing mask wearing mask contagion probability carrier wearing masks',
#  'india trying prevent people posting updates',
#  'president nigeria dismissed chief staff wellbeing challenge coronavirus',
#  'ask amazon alexa origin coronavirus pandemic says government planned',
#  'jio giving indian users free recharge',
#  'vaccine protects coronavirus',
#  'serbia stricter covid19 curfew measures prevented dog walking 14 hours time',
#  'virus could spread shoes',
#  'transmitted fruits vegetables hong kong',
#  'india lockdown due extended',
#  'depending poll 58 81 americans supportive keeping current restrictions place even expanding nation whole',
#  'chinese doctor went help italians found main reason spreads quickly italy italians like use shoes wear outside house people even bedroom',
#  'madhya pradesh chief minister shivraj singh chauhan said people violate lockdown would shot immediately',
#  'democratic nominee president joe biden received campaign donations antifa',
#  'illinois banned sale alcohol march 30 2020',
#  'confirmed tested 2 spoonfuls palm oil every morning stop spread',
#  'sri lankan military hospital kotelawala defence university hospital reserved exclusively use vips test positive',
#  'nigella sativa contains 100 hydroxychloroquine',
#  'took obama millions infected deaths declare h1n1 flu health emergency',
#  'taking nigella sativa kalonji seeds honey prevent infection',
#  'coronavirus caused serious birth defect stillborn baby rajasthan india',
#  'centers disease control prevention planning next 10 days change guidance advise americans wear masks everyday life',
#  'pm narendra modi given contract coronavirus testing kits gujurati company selling',
#  'drinking water liquids wash coronovirus oesophasgus killed stomach acid',
#  'government india going shut internet avoid panic coronavirus',
#  'coloured part surgical mask worn inwards face help prevent spread coronavirus',
#  'man pakistan threw party consisting 100 people recovering coronavirus attending party multiple people present infected virus',
#  'installation 5g united kingdom secret weapon deployment',
#  ...]

# %%
"""
Remove non letter chatacters
Lowercase
Tkenize based on lower space
Remove sentences with less than 2 tokens
"""
tokenized_sentences = [re.sub('\W', ' ', sentence).lower().split() for sentence in processed_sentences]
# remove sentences that are only 1 word long
tokenized_sentences = [sentence for sentence in tokenized_sentences if len(sentence) > 1]

for sentence in tokenized_sentences[:10]:
    print(sentence)
# Out:
# ['hunter', 'biden', 'experience', 'ukraine', 'energy', 'sector', 'joined', 'board', 'burisma']
# ['donald', 'trump', 'delivered', 'largest', 'tax', 'cuts', 'american', 'history']
# ['nigeria', 'terms', 'revenue', 'share', '20', 'goes', 'local', 'government']
# ['biden', 'pledged', 'stop', 'border', 'wall', 'construction', 'give', 'amnesty', 'health', 'care', 'illegal', 'immigrants']
# ['police', 'shooting', 'jacob', 'blake', 'gov', 'tony', 'evers', 'gov', 'mandela', 'barnes', 'call', 'peace', 'encourage', 'calm']
# ['common', 'law', 'admission', 'test', 'clat', '2020', 'conducted', 'september', '7', '2020', 'planned']
# ['35', 'revenue', 'goes', 'states', 'nigeria']
# ['margaret', 'sanger', 'racist', 'believed', 'eugenics', 'goal', 'founding', 'planned', 'parenthood', 'eradicate', 'minorities']
# ['joe', 'biden', 'voted', 'irag', 'war', 'supported', 'war', 'serbia', 'syria', 'libya']
# ['biden', 'take', 'away', 'second', 'amendment']

# %% [markdown]
# # Train W2V
# Vector size usually ranges from 100 to 300, we choose 100 to reduce the model complexity and speed up the training. We reduce the window size to 5
# since we have short sentences.

# %%
model = Word2Vec(tokenized_sentences, vector_size=100, min_count=5, window=5)

# %%
term = 'covid'

model.wv.most_similar(term)
# Out:
# [('million', 0.9903276562690735),
#  ('state', 0.9902217388153076),
#  ('nigeria', 0.9900514483451843),
#  ('country', 0.9899704456329346),
#  ('2018', 0.9899702668190002),
#  ('years', 0.9899058938026428),
#  ('government', 0.9898313283920288),
#  ('launched', 0.989829421043396),
#  ('world', 0.989748477935791),
#  ('house', 0.9896952509880066)]

# %% [markdown]
# ## Visualization with t-SNE

# %%
# sample of 50 words most close to the term 'covid'
term_1 = 'covid'
term_2='nigeria'
term_3='trump'
covid_sample=model.wv.most_similar(term_1, topn=100)
covid_terms= [tup[0] for tup in covid_sample]

nigeria_sample=model.wv.most_similar(term_2, topn=100)
nigeria_terms= [tup[0] for tup in nigeria_sample]

trump_sample=model.wv.most_similar(term_3, topn=100)
trump_terms= [tup[0] for tup in trump_sample]

# %%
covid_vectors = model.wv[covid_terms]
nigeria_vectors = model.wv[nigeria_terms]
trump_vectors = model.wv[trump_terms]

# %%
tsne = TSNE(n_components=3, n_iter=2000)
tsne_embedding_covid = tsne.fit_transform(covid_vectors)
tsne_embedding_nigeria = tsne.fit_transform(nigeria_vectors)
tsne_embedding_trump = tsne.fit_transform(trump_vectors)

# %%
combined_embeddings = [
    (tsne_embedding_covid, 'covid'),
    (tsne_embedding_nigeria, 'nigeria'),
    (tsne_embedding_trump, 'trump')
]
x_data = []
y_data = []
z_data = []
colors = []

for embedding, label in combined_embeddings:
    x_data.extend(embedding[:, 0])
    y_data.extend(embedding[:, 1])
    z_data.extend(embedding[:, 2])
    if label == 'covid':
        colors.extend(['red'] * len(embedding))
    elif label == 'nigeria':
        colors.extend(['green'] * len(embedding))
    elif label == 'trump':
        colors.extend(['blue'] * len(embedding))

# %%
fig = go.Figure(data=[go.Scatter3d(
    x=x_data,
    y=y_data,
    z=z_data,
    mode='markers',
    marker=dict(
        size=5,
        color=colors,  # assign colors based on identifiers
        opacity=0.8
    )
)])

fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))

fig.show()
